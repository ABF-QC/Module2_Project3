# %%
# regex
import re

# Pandas
import pandas as pd

# Web scraping
import requests
from bs4 import BeautifulSoup

# BeautifulSoup Object to Python dictionary converter
from soup2dict import convert

# %%
r = requests.get('https://www.rottentomatoes.com/browse/movies_at_home/')

# %%
# Create BeautifulSoup object
scrape = BeautifulSoup(r.content)

# Find all URLs
href = scrape.find_all(['a','href'])

# Print URL found
print(href)

# Qty of URL found
len(href)
# Out:
# [<a data-qa="auth-signup-screen-reset-client-link" href="/reset-client">Trouble logging in?</a>, <a data-qa="auth-signup-screen-privacy-policy-link" href="https://www.nbcuniversal.com/fandango-privacy-policy" rel="noopener" target="_blank">Privacy Policy</a>, <a data-qa="auth-signup-screen-terms-policies-link" href="/policies/terms-and-policies" rel="noopener" target="_blank">Terms and Policies</a>, <a href="https://www.fandango.com/about-us" rel="noopener" target="_blank">Fandango Media Brands</a>, <a data-qa="auth-name-screen-privacy-policy-link" href="https://www.nbcuniversal.com/fandango-privacy-policy" rel="noopener" target="_blank"> Privacy Policy </a>, <a data-qa="auth-name-screen-terms-policies-link" href="/policies/terms-and-policies" rel="noopener" target="_blank"> Terms and Policies</a>, <a data-qa="auth-name-screen-fandango-media-link" href="https://www.fandango.com/about-us" rel="noopener" target="_blank"> Fandango Media Brands</a>, <a data-qa="auth-name-screen-privacy-p
# ...
