# %% [markdown]
# ---
# # Data Cleaning
# ---
# In this notebook, it is the data cleaning section of the project.
#
# 1. Each column type and it ranges of values/category will be analyzed.
# 2. Columns that provide no valuable information will be discarded.
# 3. Missing values will be found and replaced.
# 4. Categories that are highly correleated to another column will be replaced, inorder to no pass the same information twice to the classification algorithm.
#
#
# ## The columns available in the dataset and their description:
#
# | Column name (French)      | Column name (English)               | Units  | Needed for further analysis  |
# |------------------------------------------------------------------------|----------|----------|----------|
# | Code AGB                                                                | AGB Code                                                                  | None                                   | No      |
# | Code CIQUAL                                                             | CIQUAL Code                                                              | None                                   | No      |
# | Groupe d'aliment                                                         | Food Group                                                                | None                                   | Yes      |
# | Sous-groupe d'aliment                                                    | Food Sub-group                                                            | None                                   | Yes      |
# | Nom du Produit en Français                                              | Product Name in French                                                    | None                                   | No (keeping LCI Name)      |
# | LCI Name                                                                | LCI Name                                                                  | None                                   | Yes      |
# | Code saison  | Season Code     | 0: out of season</br> 1: in season</br> 2: mixed consumption                                  | Yes      |
# | Code avion                                               | Airplane Code                                            | 1: by airplane                                 | Yes      |
# | Livraison (temperature et distance)                                     | Delivery (temperature and distance)                                                                | None                                   | Yes      |
# | Approche emballage                                                      | Packaging Approach                                                        | None                                   | Yes      |
# | Préparation (cuisson)                                                            | Preparation (cooking)                                                               | None                                   | Yes      |
# | DQR - Note de qualité de la donnée         | DQR - Data Quality Rating                     | 1 excellent</br> to</br> 5 very low                                    | No      |
# | Score unique EF 3.1                                                     | Unique EF 3.1 Score                                                       | mPt/kg de produit                      | Yes      |
# | Changement climatique                                                   | Climate Change                                                             | kg CO2 eq/kg de produit                | Yes      |
# | Appauvrissement de la couche d'ozone                                     | Ozone Layer Depletion                                                     | kg CVC11 eq/kg de produit              | Yes      |
# | Rayonnements ionisants                                                  | Ionizing Radiation                                                        | kBq U-235 eq/kg de produit             | Yes      |
# | Formation photochimique d'ozone                                         | Photochemical Ozone Formation                                             | kg NMVOC eq/kg de produit              | Yes      |
# | Particules fines                                                         | Fine Particles                                                            | disease inc./kg de produit             | Yes      |
# | Effets toxicologiques sur la santé humaine : substances non-cancérogènes | Toxicological Effects on Human Health: Non-carcinogenic Substances        | CTUh/kg de produit                     | Yes      |
# | Effets toxicologiques sur la santé humaine : substances cancérogènes    | Toxicological Effects on Human Health: Carcinogenic Substances            | CTUh/kg de produit.1                   | Yes      |
# | Acidification terrestre et eaux douces                                  | Terrestrial and Freshwater Acidification                                  | mol H+ eq/kg de produit                | Yes      |
# | Eutrophisation eaux douces                                              | Freshwater Eutrophication                                                 | kg P eq/kg de produit                  | Yes      |
# | Eutrophisation marine                                                   | Marine Eutrophication                                                     | kg N eq/kg de produit                  | Yes      |
# | Eutrophisation terrestre                                                | Terrestrial Eutrophication                                                | mol N eq/kg de produit                 | Yes      |
# | Écotoxicité pour écosystèmes aquatiques d'eau douce                      | Ecotoxicity for Freshwater Aquatic Ecosystems                             | CTUe/kg de produit                     | Yes      |
# | Utilisation du sol                                                      | Land Use                                                                  | Pt/kg de produit                       | Yes      |
# | Épuisement des ressources eau                                           | Water Resource Depletion                                                  | m3 depriv./kg de produit               | Yes      |
# | Épuisement des ressources énergétiques                                  | Energy Resource Depletion                                                 | MJ/kg de produit                       | Yes      |
# | Épuisement des ressources minéraux                                      | Mineral Resource Depletion                                                | kg Sb eq/kg de produit                 | Yes      |
# | Changement climatique - émissions biogéniques                           | Climate Change - Biogenic Emissions                                        | kg CO2 eq/kg de produit.1              | Yes      |
# | Changement climatique - émissions fossiles                              | Climate Change - Fossil Emissions                                         | kg CO2 eq/kg de produit.2              | Yes      |
# | Changement climatique - émissions liées au changement d'affectation des sols | Climate Change - Emissions from Land Use Change                           | kg CO2 eq/kg de produit.3              | Yes      |
#
# ---

# %% [markdown]
# ### Importing necessary library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read data file

# %%
df = pd.read_excel('../data/AGRIBALYSE3.2_Tableur produits alimentaires_VF_20_11_24.xlsx', sheet_name="Synthese", header=1)  
df.head()
# Out:
#    Code\nAGB  Code\nCIQUAL                        Groupe d'aliment  \
# 0  Code\nAGB  Code\nCIQUAL                        Groupe d'aliment
# 1      11172         11172  aides culinaires et ingrédients divers
# 2      25525         25525  aides culinaires et ingrédients divers
# 3      11214         11214  aides culinaires et ingrédients divers
# 4      11084         11084  aides culinaires et ingrédients divers
#
#    Sous-groupe d'aliment                         Nom du Produit en Français  \
# 0  Sous-groupe d'aliment                         Nom du Produit en Français
# 1       aides culinaires           Court-bouillon pour poissons, déshydraté
# 2       aides culinaires                        Pizza, sauce garniture pour
# 3       aides culinaires  Préparation culinaire à base de soja, type "cr...
# 4                 algues                                  Agar (algue), cru
#
#                                     LCI Name  \
# 0                                   LCI Name
# 1  Aromatic stock cube, for fish, dehydrated
# 2                    Topping sauce for pizza
# 3                    Soy "cream" preparation
# 4                         Seaweed, agar, raw
#
#   code saison (0 : hors saison ; 1 : de saison ; 2 : mix de consommation FR)  \
# 0  code saison (0 : hors saison ; 1 : de saison ;...
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    code avion (1 : par avion)       Livraison  Approche emballage   ...  \
# 0  code avion (1 : par avion)       Livraison  Approche emballage   ...
# 1                           0  Ambiant (long)           PACK PROXY  ...
# 2                           0  Ambiant (long)           PACK PROXY  ...
# 3                           0  Ambiant (long)           PACK PROXY  ...
# 4                           0  Ambiant (long)           PACK PROXY  ...
#
#    Eutrophisation marine Eutrophisation terrestre  \
# 0  kg N eq/kg de produit   mol N eq/kg de produit
# 1               0.026783                 0.137099
# 2               0.004162                 0.030263
# 3               0.007233                 0.024434
# 4               0.015034                 0.143648
#
#   Écotoxicité pour écosystèmes aquatiques d'eau douce Utilisation du sol  \
# 0                                 CTUe/kg de produit    Pt/kg de produit
# 1                                          70.183757            106.3095
# 2                                          11.027442           67.673943
# 3                                          30.835753           116.49228
# 4                                           57.86752           26.718351
#
#   Épuisement des ressources eau Épuisement des ressources énergétiques  \
# 0      m3 depriv./kg de produit                       MJ/kg de produit
# 1                      3.380742                              700.15958
# 2                      2.468103                              24.405351
# 3                      0.422468                              22.429809
# 4                      4.833158                              395.94639
#
#   Épuisement des ressources minéraux  \
# 0             kg Sb eq/kg de produit
# 1                           0.000051
# 2                           0.000006
# 3                           0.000004
# 4                           0.000079
#
#   Changement climatique - émissions biogéniques  \
# 0                       kg CO2 eq/kg de produit
# 1                                      0.103694
# 2                                      0.033626
# 3                                       0.02518
# 4                                      0.040063
#
#   Changement climatique - émissions fossiles  \
# 0                    kg CO2 eq/kg de produit
# 1                                   7.459628
# 2                                   1.015114
# 3                                   0.964544
# 4                                  11.740311
#
#   Changement climatique - émissions liées au changement d'affectation des sols
# 0                            kg CO2 eq/kg de produit
# 1                                           0.021197
# 2                                          -0.108325
# 3                                           0.184348
# 4                                           0.006545
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Remove first row
# Contains duplicated header or units information

# %%
df = df.drop(index=[0])
df
# Out:
#      Code\nAGB Code\nCIQUAL                        Groupe d'aliment  \
# 1        11172        11172  aides culinaires et ingrédients divers
# 2        25525        25525  aides culinaires et ingrédients divers
# 3        11214        11214  aides culinaires et ingrédients divers
# 4        11084        11084  aides culinaires et ingrédients divers
# 5        20995        20995  aides culinaires et ingrédients divers
# ...        ...          ...                                     ...
# 2454      6581         6581                 viandes, œufs, poissons
# 2455      6523         6523                 viandes, œufs, poissons
# 2456      6524         6524                 viandes, œufs, poissons
# 2457      6551         6551                 viandes, œufs, poissons
# 2458      6582         6582                 viandes, œufs, poissons
#
#      Sous-groupe d'aliment                         Nom du Produit en Français  \
# 1         aides culinaires           Court-bouillon pour poissons, déshydraté
# 2         aides culinaires                        Pizza, sauce garniture pour
# 3         aides culinaires  Préparation culinaire à base de soja, type "cr...
# 4                   algues                                  Agar (algue), cru
# 5                   algues  Ao-nori (Enteromorpha sp.), séchée ou déshydratée
# ...                    ...                                                ...
# 2454        viandes cuites                    Veau, jarret, braisé ou bouilli
# 2455        viandes cuites                         Veau, noix, grillée/poêlée
# 2456        viandes cuites                                  Veau, noix, rôtie
# 2457        viandes cuites                                   Veau, rôti, cuit
# 2458        viandes cuites                 Veau, tête, bouillie/cuite à l'eau
#
#                                                LCI Name  \
# 1             Aromatic stock cube, for fish, dehydrated
# 2                               Topping sauce for pizza
# 3                               Soy "cream" preparation
# 4                                    Seaweed, agar, raw
# 5     Sea lettuce (Enteromorpha sp.), dried or dehyd...
# ...                                                 ...
# 2454          Veal, knuckle or shank, braised or boiled
# 2455                Veal, tenderloin, grilled/pan-fried
# 2456                          Veal, tenderloin, roasted
# 2457                                Veal, roast, cooked
# 2458                 Calf, head, boiled/cooked in water
#
#      code saison (0 : hors saison ; 1 : de saison ; 2 : mix de consommation FR)  \
# 1                                                     2
# 2                                                     2
# 3                                                     2
# 4                                                     2
# 5                                                     2
# ...                                                 ...
# 2454                                                  2
# 2455                                                  2
# 2456                                                  2
# 2457                                                  2
# 2458                                                  2
#
#      code avion (1 : par avion)       Livraison Approche emballage   ...  \
# 1                             0  Ambiant (long)          PACK PROXY  ...
# 2                             0  Ambiant (long)          PACK PROXY  ...
# 3                             0  Ambiant (long)          PACK PROXY  ...
# 4                             0  Ambiant (long)          PACK PROXY  ...
# 5                             0  Ambiant (long)          PACK PROXY  ...
# ...                         ...             ...                 ...  ...
# 2454                          0           Glacé            PACK AGB  ...
# 2455                          0           Glacé            PACK AGB  ...
# 2456                          0           Glacé            PACK AGB  ...
# 2457                          0           Glacé            PACK AGB  ...
# 2458                          0           Glacé            PACK AGB  ...
#
#      Eutrophisation marine Eutrophisation terrestre  \
# 1                 0.026783                 0.137099
# 2                 0.004162                 0.030263
# 3                 0.007233                 0.024434
# 4                 0.015034                 0.143648
# 5                 0.015034                 0.143648
# ...                    ...                      ...
# 2454              0.091173                 1.457487
# 2455              0.091187                 1.457302
# 2456              0.091077                 1.457291
# 2457              0.113935                 1.821645
# 2458              0.091173                 1.457487
#
#      Écotoxicité pour écosystèmes aquatiques d'eau douce Utilisation du sol  \
# 1                                             70.183757            106.3095
# 2                                             11.027442           67.673943
# 3                                             30.835753           116.49228
# 4                                              57.86752           26.718351
# 5                                              57.86752           26.718351
# ...                                                 ...                 ...
# 2454                                          391.69164            1336.417
# 2455                                          392.31917           1339.1618
# 2456                                          392.24462           1336.1372
# 2457                                          490.59667           1670.0795
# 2458                                          391.69164            1336.417
#
#      Épuisement des ressources eau Épuisement des ressources énergétiques  \
# 1                         3.380742                              700.15958
# 2                         2.468103                              24.405351
# 3                         0.422468                              22.429809
# 4                         4.833158                              395.94639
# 5                         4.833158                              395.94639
# ...                            ...                                    ...
# 2454                      4.021206                              149.24438
# 2455                      3.972692                              141.89131
# 2456                      3.991295                              149.67724
# 2457                      4.984198                              184.17966
# 2458                      4.021206                              149.24438
#
#      Épuisement des ressources minéraux  \
# 1                              0.000051
# 2                              0.000006
# 3                              0.000004
# 4                              0.000079
# 5                              0.000079
# ...                                 ...
# 2454                           0.000057
# 2455                           0.000056
# 2456                           0.000059
# 2457                           0.000072
# 2458                           0.000057
#
#      Changement climatique - émissions biogéniques  \
# 1                                         0.103694
# 2                                         0.033626
# 3                                          0.02518
# 4                                         0.040063
# 5                                         0.040063
# ...                                            ...
# 2454                                     15.861507
# 2455                                     15.821821
# 2456                                      15.82174
# 2457                                     19.864699
# 2458                                     15.861507
#
#      Changement climatique - émissions fossiles  \
# 1                                      7.459628
# 2                                      1.015114
# 3                                      0.964544
# 4                                     11.740311
# 5                                     11.740311
# ...                                         ...
# 2454                                  11.205989
# 2455                                  10.946006
# 2456                                  10.910768
# 2457                                  13.630845
# 2458                                  11.205989
#
#      Changement climatique - émissions liées au changement d'affectation des sols
# 1                                              0.021197
# 2                                             -0.108325
# 3                                              0.184348
# 4                                              0.006545
# 5                                              0.006545
# ...                                                 ...
# 2454                                           2.617929
# 2455                                           2.621672
# 2456                                           2.617884
# 2457                                           3.272343
# 2458                                           2.617929
#
# [2458 rows x 32 columns]

# %% [markdown]
# ---
# ### Removing unnecessary columns
# ---

# %%
df.columns
# Out:
# Index(['Code\nAGB', 'Code\nCIQUAL', 'Groupe d'aliment',
#        'Sous-groupe d'aliment', 'Nom du Produit en Français', 'LCI Name',
#        'code saison (0 : hors saison ; 1 : de saison ; 2 : mix de consommation FR)',
#        'code avion (1 : par avion)', 'Livraison', 'Approche emballage ',
#        'Préparation',
#        'DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)',
#        'Score unique EF 3.1', 'Changement climatique',
#        'Appauvrissement de la couche d'ozone', 'Rayonnements ionisants',
#        'Formation photochimique d'ozone', 'Particules fines',
#        'Effets toxicologiques sur la santé humaine : substances non-cancérogènes',
#        'Effets toxicologiques sur la santé humaine : substances cancérogènes',
#        'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces',
#        'Eutrophisation marine', 'Eutrophisation terrestre',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce',
#        'Utilisation du sol', 'Épuisement des ressources eau',
#        'Épuisement des ressources énergétiques',
#        'Épuisement des ressources minéraux',
#        'Changement climatique - émissions biogéniques',
#        'Changement climatique - émissions fossiles',
#        'Changement climatique - émissions liées au changement d'affectation des sols'],
#       dtype='object')

# %%
df = df.drop(columns=['Code\nAGB', 
                      'Code\nCIQUAL',
                      'Nom du Produit en Français',
                      'DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)'               
                     ])

df.head()
# Out:
#                          Groupe d'aliment Sous-groupe d'aliment  \
# 1  aides culinaires et ingrédients divers      aides culinaires
# 2  aides culinaires et ingrédients divers      aides culinaires
# 3  aides culinaires et ingrédients divers      aides culinaires
# 4  aides culinaires et ingrédients divers                algues
# 5  aides culinaires et ingrédients divers                algues
#
#                                             LCI Name  \
# 1          Aromatic stock cube, for fish, dehydrated
# 2                            Topping sauce for pizza
# 3                            Soy "cream" preparation
# 4                                 Seaweed, agar, raw
# 5  Sea lettuce (Enteromorpha sp.), dried or dehyd...
#
#   code saison (0 : hors saison ; 1 : de saison ; 2 : mix de consommation FR)  \
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
# 5                                                  2
#
#   code avion (1 : par avion)       Livraison Approche emballage   \
# 1                          0  Ambiant (long)          PACK PROXY
# 2                          0  Ambiant (long)          PACK PROXY
# 3                          0  Ambiant (long)          PACK PROXY
# 4                          0  Ambiant (long)          PACK PROXY
# 5                          0  Ambiant (long)          PACK PROXY
#
#           Préparation Score unique EF 3.1 Changement climatique  ...  \
# 1  Pas de préparation            1.874152              7.584518  ...
# 2  Pas de préparation            0.148315              0.940414  ...
# 3  Pas de préparation            0.147701              1.174072  ...
# 4  Pas de préparation            1.547348              11.78692  ...
# 5  Pas de préparation            1.547348              11.78692  ...
#
#   Eutrophisation marine Eutrophisation terrestre  \
# 1              0.026783                 0.137099
# 2              0.004162                 0.030263
# 3              0.007233                 0.024434
# 4              0.015034                 0.143648
# 5              0.015034                 0.143648
#
#   Écotoxicité pour écosystèmes aquatiques d'eau douce Utilisation du sol  \
# 1                                          70.183757            106.3095
# 2                                          11.027442           67.673943
# 3                                          30.835753           116.49228
# 4                                           57.86752           26.718351
# 5                                           57.86752           26.718351
#
#   Épuisement des ressources eau Épuisement des ressources énergétiques  \
# 1                      3.380742                              700.15958
# 2                      2.468103                              24.405351
# 3                      0.422468                              22.429809
# 4                      4.833158                              395.94639
# 5                      4.833158                              395.94639
#
#   Épuisement des ressources minéraux  \
# 1                           0.000051
# 2                           0.000006
# 3                           0.000004
# 4                           0.000079
# 5                           0.000079
#
#   Changement climatique - émissions biogéniques  \
# 1                                      0.103694
# 2                                      0.033626
# 3                                       0.02518
# 4                                      0.040063
# 5                                      0.040063
#
#   Changement climatique - émissions fossiles  \
# 1                                   7.459628
# 2                                   1.015114
# 3                                   0.964544
# 4                                  11.740311
# 5                                  11.740311
#
#   Changement climatique - émissions liées au changement d'affectation des sols
# 1                                           0.021197
# 2                                          -0.108325
# 3                                           0.184348
# 4                                           0.006545
# 5                                           0.006545
#
# [5 rows x 28 columns]

# %% [markdown]
# ---
# ### Renaming columns
# ---
# (French to English)

# %%
french = df.drop(columns=['LCI Name']).columns

french
# Out:
# Index(['Groupe d'aliment', 'Sous-groupe d'aliment',
#        'code saison (0 : hors saison ; 1 : de saison ; 2 : mix de consommation FR)',
#        'code avion (1 : par avion)', 'Livraison', 'Approche emballage ',
#        'Préparation', 'Score unique EF 3.1', 'Changement climatique',
#        'Appauvrissement de la couche d'ozone', 'Rayonnements ionisants',
#        'Formation photochimique d'ozone', 'Particules fines',
#        'Effets toxicologiques sur la santé humaine : substances non-cancérogènes',
#        'Effets toxicologiques sur la santé humaine : substances cancérogènes',
#        'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces',
#        'Eutrophisation marine', 'Eutrophisation terrestre',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce',
#        'Utilisation du sol', 'Épuisement des ressources eau',
#        'Épuisement des ressources énergétiques',
#        'Épuisement des ressources minéraux',
#        'Changement climatique - émissions biogéniques',
#        'Changement climatique - émissions fossiles',
#        'Changement climatique - émissions liées au changement d'affectation des sols'],
#       dtype='object')

# %%
eng = [ 
    'Food Group', 
    'Food Sub-group', 
    'Season Code', 
    'Airplane Code', 
    'Delivery', 
    'Packaging', 
    'Preparation', 
    'EF Score', 
    'Climate Change', 
    'Ozone Layer Depletion', 
    'Ionizing Radiation', 
    'Photochemical Ozone Formation', 
    'Fine Particles', 
    'Toxicological Effects (Non-carcinogenic)', 
    'Toxicological Effects (Carcinogenic)', 
    'Terrestrial and Freshwater Acidification', 
    'Freshwater Eutrophication', 
    'Marine Eutrophication', 
    'Terrestrial Eutrophication', 
    'Ecotoxicity for Freshwater Aquatic Ecosystems', 
    'Land Use', 
    'Water Resource Depletion', 
    'Energy Resource Depletion', 
    'Mineral Resource Depletion', 
    'Climate Change - Biogenic Emissions', 
    'Climate Change - Fossil Emissions', 
    'Climate Change - Emissions from Land Use Change'
]

# %%
french2eng = dict(zip(french, eng))

df = df.rename(columns=french2eng)

df.head()
# Out:
#                                Food Group    Food Sub-group  \
# 1  aides culinaires et ingrédients divers  aides culinaires
# 2  aides culinaires et ingrédients divers  aides culinaires
# 3  aides culinaires et ingrédients divers  aides culinaires
# 4  aides culinaires et ingrédients divers            algues
# 5  aides culinaires et ingrédients divers            algues
#
#                                             LCI Name Season Code  \
# 1          Aromatic stock cube, for fish, dehydrated           2
# 2                            Topping sauce for pizza           2
# 3                            Soy "cream" preparation           2
# 4                                 Seaweed, agar, raw           2
# 5  Sea lettuce (Enteromorpha sp.), dried or dehyd...           2
#
#   Airplane Code        Delivery   Packaging         Preparation  EF Score  \
# 1             0  Ambiant (long)  PACK PROXY  Pas de préparation  1.874152
# 2             0  Ambiant (long)  PACK PROXY  Pas de préparation  0.148315
# 3             0  Ambiant (long)  PACK PROXY  Pas de préparation  0.147701
# 4             0  Ambiant (long)  PACK PROXY  Pas de préparation  1.547348
# 5             0  Ambiant (long)  PACK PROXY  Pas de préparation  1.547348
#
#   Climate Change  ... Marine Eutrophication Terrestrial Eutrophication  \
# 1       7.584518  ...              0.026783                   0.137099
# 2       0.940414  ...              0.004162                   0.030263
# 3       1.174072  ...              0.007233                   0.024434
# 4       11.78692  ...              0.015034                   0.143648
# 5       11.78692  ...              0.015034                   0.143648
#
#   Ecotoxicity for Freshwater Aquatic Ecosystems   Land Use  \
# 1                                     70.183757   106.3095
# 2                                     11.027442  67.673943
# 3                                     30.835753  116.49228
# 4                                      57.86752  26.718351
# 5                                      57.86752  26.718351
#
#   Water Resource Depletion Energy Resource Depletion  \
# 1                 3.380742                 700.15958
# 2                 2.468103                 24.405351
# 3                 0.422468                 22.429809
# 4                 4.833158                 395.94639
# 5                 4.833158                 395.94639
#
#   Mineral Resource Depletion Climate Change - Biogenic Emissions  \
# 1                   0.000051                            0.103694
# 2                   0.000006                            0.033626
# 3                   0.000004                             0.02518
# 4                   0.000079                            0.040063
# 5                   0.000079                            0.040063
#
#   Climate Change - Fossil Emissions  \
# 1                          7.459628
# 2                          1.015114
# 3                          0.964544
# 4                         11.740311
# 5                         11.740311
#
#   Climate Change - Emissions from Land Use Change
# 1                                        0.021197
# 2                                       -0.108325
# 3                                        0.184348
# 4                                        0.006545
# 5                                        0.006545
#
# [5 rows x 28 columns]

# %% [markdown]
# ---
# ### Change data type of columns
# ---

# %% [markdown]
# **Looking at the data type of the dataset columns**

# %%
df.dtypes
# Out:
# Food Group                                         object
# Food Sub-group                                     object
# LCI Name                                           object
# Season Code                                        object
# Airplane Code                                      object
# Delivery                                           object
# Packaging                                          object
# Preparation                                        object
# EF Score                                           object
# Climate Change                                     object
# Ozone Layer Depletion                              object
# Ionizing Radiation                                 object
# Photochemical Ozone Formation                      object
# Fine Particles                                     object
# Toxicological Effects (Non-carcinogenic)           object
# Toxicological Effects (Carcinogenic)               object
# Terrestrial and Freshwater Acidification           object
# Freshwater Eutrophication                          object
# Marine Eutrophication                              object
# Terrestrial Eutrophication                         object
# Ecotoxicity for Freshwater Aquatic Ecosystems      object
# Land Use                                           object
# Water Resource Depletion                           object
# Energy Resource Depletion                          object
# Mineral Resource Depletion                         object
# Climate Change - Biogenic Emissions                object
# Climate Change - Fossil Emissions                  object
# Climate Change - Emissions from Land Use Change    object
# dtype: object

# %%
col_int = ['Season Code', 'Airplane Code']

col_float = [
    'EF Score', 
    'Climate Change', 
    'Ozone Layer Depletion', 
    'Ionizing Radiation', 
    'Photochemical Ozone Formation', 
    'Fine Particles', 
    'Toxicological Effects (Non-carcinogenic)', 
    'Toxicological Effects (Carcinogenic)', 
    'Terrestrial and Freshwater Acidification', 
    'Freshwater Eutrophication', 
    'Marine Eutrophication', 
    'Terrestrial Eutrophication', 
    'Ecotoxicity for Freshwater Aquatic Ecosystems', 
    'Land Use', 
    'Water Resource Depletion', 
    'Energy Resource Depletion', 
    'Mineral Resource Depletion', 
    'Climate Change - Biogenic Emissions', 
    'Climate Change - Fossil Emissions', 
    'Climate Change - Emissions from Land Use Change'
]

dict_col_int = dict(zip(col_int, ['int'] * len(col_int)))

dict_col_float = dict(zip(col_float, ['float'] * len(col_float)))

# %%
df = df.astype(dict_col_int)

df = df.astype(dict_col_float)

df.dtypes
# Out:
# Food Group                                          object
# Food Sub-group                                      object
# LCI Name                                            object
# Season Code                                          int64
# Airplane Code                                        int64
# Delivery                                            object
# Packaging                                           object
# Preparation                                         object
# EF Score                                           float64
# Climate Change                                     float64
# Ozone Layer Depletion                              float64
# Ionizing Radiation                                 float64
# Photochemical Ozone Formation                      float64
# Fine Particles                                     float64
# Toxicological Effects (Non-carcinogenic)           float64
# Toxicological Effects (Carcinogenic)               float64
# Terrestrial and Freshwater Acidification           float64
# Freshwater Eutrophication                          float64
# Marine Eutrophication                              float64
# Terrestrial Eutrophication                         float64
# Ecotoxicity for Freshwater Aquatic Ecosystems      float64
# Land Use                                           float64
# Water Resource Depletion                           float64
# Energy Resource Depletion                          float64
# Mineral Resource Depletion                         float64
# Climate Change - Biogenic Emissions                float64
# Climate Change - Fossil Emissions                  float64
# Climate Change - Emissions from Land Use Change    float64
# dtype: object

# %% [markdown]
# ---
# ### Removing error rows
# ---
# There are 7 duplicated rows (with errors and without). Need to use the 'LCI Name' column to remove rows containing 'error'.

# %%
df = df[~df['LCI Name'].str.contains('error')]

df
# Out:
#                                   Food Group    Food Sub-group  \
# 1     aides culinaires et ingrédients divers  aides culinaires
# 2     aides culinaires et ingrédients divers  aides culinaires
# 3     aides culinaires et ingrédients divers  aides culinaires
# 4     aides culinaires et ingrédients divers            algues
# 5     aides culinaires et ingrédients divers            algues
# ...                                      ...               ...
# 2454                 viandes, œufs, poissons    viandes cuites
# 2455                 viandes, œufs, poissons    viandes cuites
# 2456                 viandes, œufs, poissons    viandes cuites
# 2457                 viandes, œufs, poissons    viandes cuites
# 2458                 viandes, œufs, poissons    viandes cuites
#
#                                                LCI Name  Season Code  \
# 1             Aromatic stock cube, for fish, dehydrated            2
# 2                               Topping sauce for pizza            2
# 3                               Soy "cream" preparation            2
# 4                                    Seaweed, agar, raw            2
# 5     Sea lettuce (Enteromorpha sp.), dried or dehyd...            2
# ...                                                 ...          ...
# 2454          Veal, knuckle or shank, braised or boiled            2
# 2455                Veal, tenderloin, grilled/pan-fried            2
# 2456                          Veal, tenderloin, roasted            2
# 2457                                Veal, roast, cooked            2
# 2458                 Calf, head, boiled/cooked in water            2
#
#       Airplane Code        Delivery   Packaging         Preparation  EF Score  \
# 1                 0  Ambiant (long)  PACK PROXY  Pas de préparation  1.874152
# 2                 0  Ambiant (long)  PACK PROXY  Pas de préparation  0.148315
# 3                 0  Ambiant (long)  PACK PROXY  Pas de préparation  0.147701
# 4                 0  Ambiant (long)  PACK PROXY  Pas de préparation  1.547348
# 5                 0  Ambiant (long)  PACK PROXY  Pas de préparation  1.547348
# ...             ...             ...         ...                 ...       ...
# 2454              0           Glacé    PACK AGB     Cuisson à l'eau  2.744841
# 2455              0           Glacé    PACK AGB               Poêle  2.719832
# 2456              0           Glacé    PACK AGB                Four  2.738488
# 2457              0           Glacé    PACK AGB                Four  3.418940
# 2458              0           Glacé    PACK AGB     Cuisson à l'eau  2.744841
#
#       Climate Change  ...  Marine Eutrophication  Terrestrial Eutrophication  \
# 1           7.584518  ...               0.026783                    0.137099
# 2           0.940414  ...               0.004162                    0.030263
# 3           1.174072  ...               0.007233                    0.024434
# 4          11.786920  ...               0.015034                    0.143648
# 5          11.786920  ...               0.015034                    0.143648
# ...              ...  ...                    ...                         ...
# 2454       29.685425  ...               0.091173                    1.457487
# 2455       29.389500  ...               0.091187                    1.457302
# 2456       29.350392  ...               0.091077                    1.457291
# 2457       36.767887  ...               0.113935                    1.821645
# 2458       29.685425  ...               0.091173                    1.457487
#
#       Ecotoxicity for Freshwater Aquatic Ecosystems     Land Use  \
# 1                                         70.183757   106.309500
# 2                                         11.027442    67.673943
# 3                                         30.835753   116.492280
# 4                                         57.867520    26.718351
# 5                                         57.867520    26.718351
# ...                                             ...          ...
# 2454                                     391.691640  1336.417000
# 2455                                     392.319170  1339.161800
# 2456                                     392.244620  1336.137200
# 2457                                     490.596670  1670.079500
# 2458                                     391.691640  1336.417000
#
#       Water Resource Depletion  Energy Resource Depletion  \
# 1                     3.380742                 700.159580
# 2                     2.468103                  24.405351
# 3                     0.422468                  22.429809
# 4                     4.833158                 395.946390
# 5                     4.833158                 395.946390
# ...                        ...                        ...
# 2454                  4.021206                 149.244380
# 2455                  3.972692                 141.891310
# 2456                  3.991295                 149.677240
# 2457                  4.984198                 184.179660
# 2458                  4.021206                 149.244380
#
#       Mineral Resource Depletion  Climate Change - Biogenic Emissions  \
# 1                       0.000051                             0.103694
# 2                       0.000006                             0.033626
# 3                       0.000004                             0.025180
# 4                       0.000079                             0.040063
# 5                       0.000079                             0.040063
# ...                          ...                                  ...
# 2454                    0.000057                            15.861507
# 2455                    0.000056                            15.821821
# 2456                    0.000059                            15.821740
# 2457                    0.000072                            19.864699
# 2458                    0.000057                            15.861507
#
#       Climate Change - Fossil Emissions  \
# 1                              7.459628
# 2                              1.015114
# 3                              0.964544
# 4                             11.740311
# 5                             11.740311
# ...                                 ...
# 2454                          11.205989
# 2455                          10.946006
# 2456                          10.910768
# 2457                          13.630845
# 2458                          11.205989
#
#       Climate Change - Emissions from Land Use Change
# 1                                            0.021197
# 2                                           -0.108325
# 3                                            0.184348
# 4                                            0.006545
# 5                                            0.006545
# ...                                               ...
# 2454                                         2.617929
# 2455                                         2.621672
# 2456                                         2.617884
# 2457                                         3.272343
# 2458                                         2.617929
#
# [2451 rows x 28 columns]

# %% [markdown]
# ---
# ### Investigating missing values
# ---

# %%
df.isna().sum()
# Out:
# Food Group                                         0
# Food Sub-group                                     0
# LCI Name                                           0
# Season Code                                        0
# Airplane Code                                      0
# Delivery                                           0
# Packaging                                          0
# Preparation                                        0
# EF Score                                           0
# Climate Change                                     0
# Ozone Layer Depletion                              0
# Ionizing Radiation                                 0
# Photochemical Ozone Formation                      0
# Fine Particles                                     0
# Toxicological Effects (Non-carcinogenic)           0
# Toxicological Effects (Carcinogenic)               0
# Terrestrial and Freshwater Acidification           0
# Freshwater Eutrophication                          0
# Marine Eutrophication                              0
# Terrestrial Eutrophication                         0
# Ecotoxicity for Freshwater Aquatic Ecosystems      0
# Land Use                                           0
# Water Resource Depletion                           0
# Energy Resource Depletion                          0
# Mineral Resource Depletion                         0
# Climate Change - Biogenic Emissions                0
# Climate Change - Fossil Emissions                  0
# Climate Change - Emissions from Land Use Change    0
# dtype: int64

# %% [markdown]
# ---
# ### Investigating the values of object columns
# ---

# %% [markdown]
# **Food Group**

# %%
print('There are ',len(df['Food Group'].unique()),'categories.')

df['Food Group'].unique()
# Out:
# There are  11 categories.
# array(['aides culinaires et ingrédients divers', 'aliments infantiles',
#        'boissons', 'entrées et plats composés',
#        'fruits, légumes, légumineuses et oléagineux', 'glaces et sorbets',
#        'lait et produits laitiers', 'matières grasses',
#        'produits céréaliers', 'produits sucrés',
#        'viandes, œufs, poissons'], dtype=object)

# %% [markdown]
# **Food Sub-group**

# %%
print('There are ',len(df['Food Sub-group'].unique()),'categories.')

df['Food Sub-group'].unique()
# Out:
# There are  61 categories.
# array(['aides culinaires', 'algues', 'condiments',
#        'denrées destinées à une alimentation particulière', 'épices',
#        'herbes', 'ingrédients divers', 'sauces', 'sels',
#        'céréales et biscuits infantiles', 'desserts infantiles',
#        'laits et boissons infantiles',
#        'petits pots salés et plats infantiles', 'boisson alcoolisées',
#        'boissons sans alcool', 'eaux', 'feuilletées et autres entrées',
#        'pizzas, tartes et crêpes salées', 'plats composés',
#        'plats végétariens', 'salades composées et crudités', 'sandwichs',
#        'soupes', 'fruits', 'fruits à coque et graines oléagineuses',
#        'légumes', 'légumineuses', 'pommes de terre et autres tubercules',
#        'desserts glacés', 'glaces', 'sorbets',
#        'crèmes et spécialités à base de crème', 'fromages', 'laits',
#        'produits laitiers frais et assimilés', 'autres matières grasses',
#        'beurres', 'huiles de poissons', 'huiles et graisses végétales',
#        'margarines', 'céréales de petit-déjeuner et biscuits',
#        'farines et pâtes à tarte', 'gâteaux et pâtisseries',
#        'pains et viennoiseries', 'pâtes, riz et céréales',
#        'chocolats et produits à base de chocolat',
#        'confiseries non chocolatées', 'confitures et assimilés',
#        'sucres, miels et assimilés', 'autres produits à base de viande',
#        'charcuteries', 'mollusques et crustacés crus',
#        'mollusques et crustacés cuits', 'œufs', 'poissons crus',
#        'poissons cuits',
#        'produits à base de poissons et produits de la mer',
#        'substituts de charcuterie', 'substituts de viande',
#        'viandes crues', 'viandes cuites'], dtype=object)

# %% [markdown]
# **LCI Name**

# %%
print('There are ',len(df['LCI Name'].unique()),'categories.')
# Out:
# There are  2448 categories.

# %% [markdown]
# **Delivery**

# %%
print('There are ',len(df['Delivery'].unique()),'categories.')

df['Delivery'].unique()
# Out:
# There are  5 categories.
# array(['Ambiant (long)', 'Glacé', 'Congelé', 'Ambiant (moyen)',
#        'Ambiant (court)'], dtype=object)

# %% [markdown]
# **Packaging**

# %%
print('There are ',len(df['Packaging'].unique()),'categories.')

df['Packaging'].unique()
# Out:
# There are  2 categories.
# array(['PACK PROXY', 'PACK AGB'], dtype=object)

# %% [markdown]
# **Preparation**

# %%
print('There are ',len(df['Preparation'].unique()),'categories.')

df['Preparation'].unique()
# Out:
# There are  8 categories.
# array(['Pas de préparation', 'Micro-onde ',
#        'Réfrigéré chez le consommateur', "Cuisson à l'eau", 'Four ',
#        'Four', 'Poêle', 'Micro-onde'], dtype=object)

# %% [markdown]
# ---
# ### Cleaning the Preparation column
# ---
# There are categories that are repeated with a white space at the end.

# %%
df['Preparation'] = df['Preparation'].str.strip()

# %% [markdown]
# ---
# ### Write cleaned data file
# ---

# %%
df.to_excel('../data/AGRIBALYSE3.2_Synthese_cleaned.xlsx', index=False)
